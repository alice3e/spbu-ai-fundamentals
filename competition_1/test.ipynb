# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Модели и обработка
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_log_error # Используем метрику, близкую к Kaggle (RMSLE -> MSLE)
from sklearn.model_selection import train_test_split # Для оценки на отложенной выборке

# %%
# Настройки для визуализации
#%matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
pd.set_option('display.max_columns', None) # Показывать все колонки

# %%
# Загрузка данных
train_df = pd.read_csv('train_hw.csv', sep=',')
test_df = pd.read_csv('test_hw.csv', sep=',')

# %%
print(f"Размер трейна: {train_df.shape}")
print(f"Размер теста: {test_df.shape}")
# Out:
# Размер трейна: (1168, 81)
# Размер теста: (292, 80)

# %%
# Сохраним ID для финального файла предсказаний
train_ids = train_df['Id']
test_ids = test_df['Id']

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1         190       RL         75.0    10382   Pave   NaN      Reg
# 1   2          20       RL          NaN    10708   Pave   NaN      IR1
# 2   3          60       RL          NaN    24682   Pave   NaN      IR3
# 3   4         160       RM         42.0     3964   Pave   NaN      Reg
# 4   5          20       RL         75.0    10125   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1         Lvl    AllPub    Inside       Gtl      ClearCr       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      Gilbert       RRAn
# 3         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 4         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm   2fmCon       SLvl            6            5       1958
# 1       Norm     1Fam     1Story            5            5       1955
# 2       Norm     1Fam     2Story            6            5       1999
# 3       Norm   TwnhsE     2Story            6            4       1973
# 4       Norm     1Fam     1Story            6            6       1977
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1958       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1          1993       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 2          1999     Gable  CompShg     VinylSd     VinylSd        NaN
# 3          1973     Gable  CompShg     CemntBd     CmentBd        NaN
# 4          1977     Gable  CompShg     Plywood     Plywood        NaN
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       105.0        TA        Fa     CBlock       TA       TA           Gd
# 1         0.0        Gd        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3         0.0        TA        TA     CBlock       Gd       TA           No
# 4         0.0        TA        TA     CBlock       TA       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          ALQ         513          Unf           0         75          588
# 1          LwQ         379          BLQ         768        470         1617
# 2          Unf           0          Unf           0        841          841
# 3          ALQ         837          Unf           0        105          942
# 4          ALQ         641          LwQ         279        276         1196
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr      1095         0             0
# 1    GasA        Ex          Y      FuseA      1867         0             0
# 2    GasA        Ex          Y      SBrkr       892       783             0
# 3    GasA        Gd          Y      SBrkr      1291      1230             0
# 4    GasA        TA          Y      SBrkr      1279         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1095             1             0         1         0             2
# 1       1867             1             0         1         0             2
# 2       1675             0             0         2         1             3
# 3       2521             1             0         2         1             5
# 4       1279             0             1         2         0             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             6        Typ           0         NaN
# 1             1          TA             7        Typ           3          Gd
# 2             1          TA             7        Typ           1          TA
# 3             1          TA            10       Maj1           1          Gd
# 4             1          TA             6        Typ           2          Fa
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1958.0          RFn           1         264         TA
# 1     Attchd       1955.0          Fin           1         303         TA
# 2    BuiltIn       1999.0          Fin           2         502         TA
# 3     Attchd       1973.0          Fin           2         576         TA
# 4     Detchd       1980.0          Unf           2         473         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0            0              0          0
# 1         TA          Y         476            0              0          0
# 2         TA          Y           0          103              0          0
# 3         TA          Y         728           20              0          0
# 4         TA          Y         238           83              0          0
#
#    ScreenPorch  PoolArea  PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0     NaN    NaN         NaN        0       3    2006
# 1          142         0     NaN   GdWo         NaN        0      11    2009
# 2            0         0     NaN    NaN         NaN        0       6    2009
# 3            0         0     NaN  GdPrv         NaN        0       6    2006
# 4            0         0     NaN  MnPrv         NaN        0       2    2008
#
#   SaleType SaleCondition
# 0    ConLD        Normal
# 1      COD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
# Логарифмируем целевую переменную (SalePrice) - ВАЖНЫЙ ШАГ!
# Используем log1p для обработки возможных нулей (хотя в ценах их нет)
train_df['SalePrice'] = np.log1p(train_df['SalePrice'])
y_train_log = train_df['SalePrice']
train_features = train_df.drop('SalePrice', axis=1)
test_features = test_df.copy()

# %%
# Объединим трейн и тест для одинаковой обработки признаков
all_features = pd.concat((train_features, test_features)).reset_index(drop=True)
print(f"Размер объединенных данных: {all_features.shape}")
# Out:
# Размер объединенных данных: (1460, 80)

# %%
# Определяем типы колонок
numeric_cols = all_features.select_dtypes(include=np.number).columns.tolist()
categorical_cols = all_features.select_dtypes(include='object').columns.tolist()
categorical_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
numeric_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# Для некоторых категориальных фичей NaN имеет смысл 'None' (нет гаража, подвала и т.д.)
cols_fill_none = [
    'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu',
    'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
    'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'
]
for col in cols_fill_none:
    if col in all_features.columns:
        all_features[col] = all_features[col].fillna('None')

# %%
# Оставшиеся категориальные пропуски заполняем модой
for col in categorical_cols:
    if all_features[col].isnull().any():
        mode_val = all_features[col].mode()[0]
        all_features[col] = all_features[col].fillna(mode_val)
        print(f"   - Категориальный столбец '{col}' заполнен модой ('{mode_val}')")
# Out:
#    - Категориальный столбец 'Electrical' заполнен модой ('SBrkr')

# %%
# Числовые пропуски заполняем медианой (более устойчива к выбросам)
for col in numeric_cols:
    if all_features[col].isnull().any():
        median_val = all_features[col].median()
        all_features[col] = all_features[col].fillna(median_val)
        print(f"   - Числовой столбец '{col}' заполнен медианой ({median_val:.2f})")
# Out:
#    - Числовой столбец 'LotFrontage' заполнен медианой (69.00)
#    - Числовой столбец 'MasVnrArea' заполнен медианой (0.00)
#    - Числовой столбец 'GarageYrBlt' заполнен медианой (1980.00)

# %%
print(f"\nПропусков после заполнения: {all_features.isnull().sum().sum()}")
# Out:
# Пропусков после заполнения: 0

# %%
# Логарифмирование числовых признаков с высокой асимметрией
# Это помогает сделать их распределение более нормальным, что полезно для линейных моделей
skewness = all_features[numeric_cols].apply(lambda x: x.skew()).sort_values(ascending=False)
high_skew = skewness[abs(skewness) > 0.75] # Порог можно подбирать
skewed_features = high_skew.index
print(f"   - Найдено {len(skewed_features)} асимметричных признаков для логарифмирования.")
# Out:
#    - Найдено 12 асимметричных признаков для логарифмирования.

# %%
for col in skewed_features:
    all_features[col] = np.log1p(all_features[col])

# %%
# Кодирование категориальных признаков (One-Hot Encoding)
all_features_encoded = pd.get_dummies(all_features, columns=categorical_cols, drop_first=True, dtype=int) # Используем dtype=int для экономии памяти
print(f"   - Размер данных после OHE: {all_features_encoded.shape}")
# Out:
# 2.3 Кодирование категориальных признаков (One-Hot Encoding)...
#    - Размер данных после OHE: (1460, 260)

# %%
X_train_processed = all_features_encoded[:len(train_df)]
X_test_processed = all_features_encoded[len(train_df):]

print(f"\nРазмер обработанного трейна: {X_train_processed.shape}")
print(f"Размер обработанного теста: {X_test_processed.shape}")
# Out:
# Размер обработанного трейна: (1168, 260)
# Размер обработанного теста: (292, 260)

# %%
# StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_processed)
X_test_scaled = scaler.transform(X_test_processed) # Применяем тот же scaler к тесту

# %%
# Преобразуем обратно в DataFrame для удобства (хотя для моделей это не обязательно)
# Имена колонок теряются после scaler, создаем новые или используем старые
X_train_scaled_df = pd.DataFrame(X_train_scaled, index=X_train_processed.index, columns=X_train_processed.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, index=X_test_processed.index, columns=X_test_processed.columns)

# %%
X_train_scaled_df.head()
# Out:
#          Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.730569   -1.092671     0.130859 -0.050488    -0.784733     0.414663
# 1 -1.727603    1.844188    -3.367363 -2.651943    -0.784733     0.414663
# 2 -1.724637    0.444838     0.570260  0.166967    -0.072559     0.414663
# 3 -1.721671    1.432378     0.130859 -1.374147    -0.072559    -0.500887
# 4 -1.718705    0.853708     0.130859  0.901000    -0.784733     1.330212
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0  -0.060571     -0.721184    0.838219    0.827618   -0.354424   0.027123
# 1  -0.060571     -0.721184    1.371061    0.801363   -0.354424  -3.301939
# 2  -0.260328     -1.011697    1.425270    0.759351    2.545494  -3.301939
# 3   0.904920      0.682963    1.488175    0.848957   -0.354424   0.215966
# 4  -0.260328     -1.011697    0.884612    0.894862   -0.354424  -0.042566
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0     0.143065 -0.317240 -0.839023     -0.135024  -1.051651      1.105320
# 1     0.030787 -1.151818  1.116728     -0.135024  -0.128486     -0.818694
# 2     0.038996 -1.021233  1.209453     -0.135024   0.366400      1.105320
# 3     0.223900  0.301786 -0.839023     -0.135024  -0.454086      1.105320
# 4     0.199624  0.114252 -0.839023     -0.135024  -0.635119      1.105320
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0     -0.238149 -1.002515 -0.758692      0.207730     -0.198015     -0.922638
# 1     -0.238149 -1.002515  1.237146      0.207730     -0.198015      0.322470
# 2     -0.238149 -1.002515  1.237146      1.451981     -0.198015      0.322470
# 3     -0.238149  0.807281 -0.758692     -1.036520     -0.198015     -0.922638
# 4     -0.238149 -1.002515 -0.758692      0.207730     -0.198015     -0.300084
#
#    Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0   -0.958183    -0.239496    0.295763    1.967848   -0.930014    -1.089403
# 1   -0.958183    -0.363545    0.295763   -0.172237   -0.930014     0.583638
# 2   -0.958183    -0.611643    0.295763   -0.162972    1.305260     1.162287
# 3   -0.958183     0.835598    0.295763   -0.348261   -0.930014     1.560981
# 4    0.589753    -0.611643    0.295763    0.031581    1.163836    -1.089403
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea   MiscVal    MoSold  \
# 0      -0.409035  -0.125051    -0.292162 -0.077645 -0.192872  0.619846
# 1      -0.409035  -0.125051    -0.292162 -0.077645 -0.192872 -0.486030
# 2      -0.409035  -0.125051     3.443043 -0.077645 -0.192872 -0.117405
# 3      -0.409035  -0.125051    -0.292162 -0.077645 -0.192872 -0.117405
# 4      -0.409035  -0.125051    -0.292162 -0.077645 -0.192872 -0.854656
#
#      YrSold  MSZoning_FV  MSZoning_RH  MSZoning_RL  MSZoning_RM  Street_Pave  \
# 0  0.900748    -0.220168    -0.114059     0.523181    -0.416976     0.071858
# 1  0.900748    -0.220168    -0.114059    -1.911383     2.398217     0.071858
# 2  0.148730    -0.220168    -0.114059     0.523181    -0.416976     0.071858
# 3  0.900748    -0.220168    -0.114059    -1.911383     2.398217     0.071858
# 4  1.652766    -0.220168    -0.114059     0.523181    -0.416976     0.071858
#
#    Alley_None  Alley_Pave  LotShape_IR2  LotShape_IR3  LotShape_Reg  \
# 0    0.254405   -0.170514      -0.16512     -0.071858     -1.312483
# 1    0.254405   -0.170514      -0.16512     -0.071858      0.761915
# 2    0.254405   -0.170514      -0.16512     -0.071858      0.761915
# 3    0.254405   -0.170514      -0.16512     -0.071858      0.761915
# 4    0.254405   -0.170514      -0.16512     -0.071858     -1.312483
#
#    LandContour_HLS  LandContour_Low  LandContour_Lvl  Utilities_NoSeWa  \
# 0        -0.197853        -0.156721         0.350823         -0.029273
# 1        -0.197853        -0.156721         0.350823         -0.029273
# 2        -0.197853        -0.156721         0.350823         -0.029273
# 3        -0.197853        -0.156721         0.350823         -0.029273
# 4        -0.197853        -0.156721         0.350823         -0.029273
#
#    LotConfig_CulDSac  LotConfig_FR2  LotConfig_FR3  LotConfig_Inside  \
# 0          -0.246686      -0.188311      -0.058621          0.623557
# 1          -0.246686      -0.188311      -0.058621          0.623557
# 2          -0.246686      -0.188311      -0.058621          0.623557
# 3          -0.246686       5.310367      -0.058621         -1.603704
# 4          -0.246686      -0.188311      -0.058621         -1.603704
#
#    LandSlope_Mod  LandSlope_Sev  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0      -0.224410      -0.088121             -0.041416            -0.092928
# 1      -0.224410      -0.088121             -0.041416            10.761041
# 2       4.456135      -0.088121             -0.041416            -0.092928
# 3      -0.224410      -0.088121             -0.041416            -0.092928
# 4      -0.224410      -0.088121             -0.041416            -0.092928
#
#    Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 0              -0.20476             -0.125109             -0.328876
# 1              -0.20476             -0.125109             -0.328876
# 2              -0.20476             -0.125109             -0.328876
# 3              -0.20476             -0.125109             -0.328876
# 4              -0.20476             -0.125109             -0.328876
#
#    Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 0             -0.188311             -0.261951             -0.228588
# 1             -0.188311             -0.261951             -0.228588
# 2             -0.188311             -0.261951             -0.228588
# 3             -0.188311             -0.261951             -0.228588
# 4             -0.188311             -0.261951             -0.228588
#
#    Neighborhood_IDOTRR  Neighborhood_MeadowV  Neighborhood_Mitchel  \
# 0            -0.159565             -0.110144             -0.190735
# 1            -0.159565             -0.110144             -0.190735
# 2            -0.159565             -0.110144             -0.190735
# 3            -0.159565             -0.110144              5.242881
# 4            -0.159565             -0.110144             -0.190735
#
#    Neighborhood_NAmes  Neighborhood_NPkVill  Neighborhood_NWAmes  \
# 0            2.335174             -0.083045            -0.232705
# 1           -0.428234             -0.083045            -0.232705
# 2            2.335174             -0.083045            -0.232705
# 3           -0.428234             -0.083045            -0.232705
# 4            2.335174             -0.083045            -0.232705
#
#    Neighborhood_NoRidge  Neighborhood_NridgHt  Neighborhood_OldTown  \
# 0             -0.170514             -0.244727             -0.294129
# 1             -0.170514             -0.244727             -0.294129
# 2             -0.170514             -0.244727             -0.294129
# 3             -0.170514             -0.244727             -0.294129
# 4             -0.170514             -0.244727             -0.294129
#
#    Neighborhood_SWISU  Neighborhood_Sawyer  Neighborhood_SawyerW  \
# 0           -0.125109            -0.232705             -0.211477
# 1           -0.125109            -0.232705             -0.211477
# 2           -0.125109            -0.232705             -0.211477
# 3           -0.125109            -0.232705             -0.211477
# 4           -0.125109            -0.232705             -0.211477
#
#    Neighborhood_Somerst  Neighborhood_StoneBr  Neighborhood_Timber  \
# 0             -0.258199             -0.135309            -0.173154
# 1             -0.258199             -0.135309            -0.173154
# 2             -0.258199             -0.135309            -0.173154
# 3             -0.258199             -0.135309            -0.173154
# 4             -0.258199             -0.135309            -0.173154
#
#    Neighborhood_Veenker  Condition1_Feedr  Condition1_Norm  Condition1_PosA  \
# 0             -0.088121         -0.246686         0.399851        -0.071858
# 1             -0.088121         -0.246686         0.399851        -0.071858
# 2             -0.088121         -0.246686         0.399851        -0.071858
# 3             -0.088121         -0.246686         0.399851        -0.071858
# 4             -0.088121         -0.246686         0.399851        -0.071858
#
#    Condition1_PosN  Condition1_RRAe  Condition1_RRAn  Condition1_RRNe  \
# 0        -0.114059        -0.092928        -0.128593        -0.041416
# 1        -0.114059        -0.092928        -0.128593        -0.041416
# 2        -0.114059        -0.092928        -0.128593        -0.041416
# 3        -0.114059        -0.092928        -0.128593        -0.041416
# 4        -0.114059        -0.092928        -0.128593        -0.041416
#
#    Condition1_RRNn  Condition2_Feedr  Condition2_Norm  Condition2_PosA  \
# 0        -0.058621         -0.071858         0.114059        -0.029273
# 1        -0.058621         -0.071858         0.114059        -0.029273
# 2        -0.058621         -0.071858         0.114059        -0.029273
# 3        -0.058621         -0.071858         0.114059        -0.029273
# 4        -0.058621         -0.071858         0.114059        -0.029273
#
#    Condition2_PosN  Condition2_RRAe  Condition2_RRAn  Condition2_RRNn  \
# 0        -0.041416        -0.029273        -0.029273        -0.041416
# 1        -0.041416        -0.029273        -0.029273        -0.041416
# 2        -0.041416        -0.029273        -0.029273        -0.041416
# 3        -0.041416        -0.029273        -0.029273        -0.041416
# 4        -0.041416        -0.029273        -0.029273        -0.041416
#
#    BldgType_2fmCon  BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  \
# 0        -0.138554        -0.195505       -0.173154        -0.299253
# 1        -0.138554        -0.195505       -0.173154         3.341656
# 2        -0.138554        -0.195505       -0.173154        -0.299253
# 3        -0.138554        -0.195505       -0.173154         3.341656
# 4        -0.138554        -0.195505       -0.173154        -0.299253
#
#    HouseStyle_1.5Unf  HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 0          -0.106092           0.963012          -0.071858          -0.092928
# 1          -0.106092          -1.038408          -0.071858          -0.092928
# 2          -0.106092          -1.038408          -0.071858          -0.092928
# 3          -0.106092           0.963012          -0.071858          -0.092928
# 4          -0.106092          -1.038408          -0.071858          -0.092928
#
#    HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Gable  \
# 0          -0.650119          -0.162364        -0.209258         0.536434
# 1           1.538179          -0.162364        -0.209258         0.536434
# 2           1.538179          -0.162364        -0.209258         0.536434
# 3          -0.650119          -0.162364        -0.209258        -1.864161
# 4          -0.650119          -0.162364         4.778780        -1.864161
#
#    RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# 0          -0.083045      -0.505879          -0.058621       -0.041416
# 1          -0.083045      -0.505879          -0.058621       -0.041416
# 2          -0.083045      -0.505879          -0.058621       -0.041416
# 3          -0.083045       1.976756          -0.058621       -0.041416
# 4          -0.083045       1.976756          -0.058621       -0.041416
#
#    RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# 0           0.14173               0.0       -0.029273      -0.029273
# 1           0.14173               0.0       -0.029273      -0.029273
# 2           0.14173               0.0       -0.029273      -0.029273
# 3           0.14173               0.0       -0.029273      -0.029273
# 4           0.14173               0.0       -0.029273      -0.029273
#
#    RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  Exterior1st_AsphShn  \
# 0         -0.088121         -0.065568         -0.071858            -0.029273
# 1         -0.088121         -0.065568         -0.071858            -0.029273
# 2         -0.088121         -0.065568         -0.071858            -0.029273
# 3         -0.088121         -0.065568         -0.071858            -0.029273
# 4         -0.088121         -0.065568         -0.071858            -0.029273
#
#    Exterior1st_BrkComm  Exterior1st_BrkFace  Exterior1st_CBlock  \
# 0            -0.029273            -0.193133           -0.029273
# 1            -0.029273            -0.193133           -0.029273
# 2            -0.029273            -0.193133           -0.029273
# 3            -0.029273            -0.193133           -0.029273
# 4            -0.029273            -0.193133           -0.029273
#
#    Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 0            -0.209258            -0.429633            -0.029273
# 1            -0.209258             2.327570            -0.029273
# 2            -0.209258             2.327570            -0.029273
# 3            -0.209258            -0.429633            -0.029273
# 4            -0.209258            -0.429633            -0.029273
#
#    Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 0             2.358346            -0.276582          -0.041416
# 1            -0.424026            -0.276582          -0.041416
# 2            -0.424026            -0.276582          -0.041416
# 3            -0.424026            -0.276582          -0.041416
# 4            -0.424026            -0.276582          -0.041416
#
#    Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 0           -0.128593            -0.735457            -0.404162
# 1           -0.128593            -0.735457            -0.404162
# 2           -0.128593            -0.735457            -0.404162
# 3           -0.128593             1.359699            -0.404162
# 4           -0.128593            -0.735457             2.474258
#
#    Exterior1st_WdShing  Exterior2nd_AsphShn  Exterior2nd_Brk Cmn  \
# 0            -0.128593            -0.050746            -0.065568
# 1            -0.128593            -0.050746            -0.065568
# 2            -0.128593            -0.050746            -0.065568
# 3            -0.128593            -0.050746            -0.065568
# 4            -0.128593            -0.050746            -0.065568
#
#    Exterior2nd_BrkFace  Exterior2nd_CBlock  Exterior2nd_CmentBd  \
# 0            -0.135309           -0.029273             -0.20702
# 1            -0.135309           -0.029273             -0.20702
# 2            -0.135309           -0.029273             -0.20702
# 3            -0.135309           -0.029273             -0.20702
# 4            -0.135309           -0.029273             -0.20702
#
#    Exterior2nd_HdBoard  Exterior2nd_ImStucc  Exterior2nd_MetalSd  \
# 0            -0.404162            -0.088121             2.374103
# 1             2.474258            -0.088121            -0.421212
# 2             2.474258            -0.088121            -0.421212
# 3            -0.404162            -0.088121            -0.421212
# 4             2.474258            -0.088121            -0.421212
#
#    Exterior2nd_Other  Exterior2nd_Plywood  Exterior2nd_Stone  \
# 0          -0.029273            -0.327275          -0.065568
# 1          -0.029273            -0.327275          -0.065568
# 2          -0.029273            -0.327275          -0.065568
# 3          -0.029273            -0.327275          -0.065568
# 4          -0.029273            -0.327275          -0.065568
#
#    Exterior2nd_Stucco  Exterior2nd_VinylSd  Exterior2nd_Wd Sdng  \
# 0           -0.128593            -0.720316             -0.39262
# 1           -0.128593            -0.720316             -0.39262
# 2           -0.128593            -0.720316             -0.39262
# 3           -0.128593             1.388279             -0.39262
# 4           -0.128593            -0.720316             -0.39262
#
#    Exterior2nd_Wd Shng  MasVnrType_BrkFace  MasVnrType_None  MasVnrType_Stone  \
# 0            -0.167836            1.513321        -1.210014         -0.317566
# 1            -0.167836           -0.660798         0.826436         -0.317566
# 2            -0.167836            1.513321        -1.210014         -0.317566
# 3            -0.167836            1.513321        -1.210014         -0.317566
# 4            -0.167836            1.513321        -1.210014         -0.317566
#
#    ExterQual_Fa  ExterQual_Gd  ExterQual_TA  ExterCond_Fa  ExterCond_Gd  \
# 0     -0.110144     -0.710742      0.790239     -0.138554     -0.319197
# 1     -0.110144     -0.710742      0.790239     -0.138554     -0.319197
# 2     -0.110144     -0.710742      0.790239     -0.138554     -0.319197
# 3     -0.110144     -0.710742      0.790239     -0.138554     -0.319197
# 4     -0.110144     -0.710742      0.790239     -0.138554     -0.319197
#
#    ExterCond_Po  ExterCond_TA  Foundation_CBlock  Foundation_PConc  \
# 0     -0.029273      0.359991           1.147807         -0.909866
# 1     -0.029273      0.359991           1.147807         -0.909866
# 2     -0.029273      0.359991           1.147807         -0.909866
# 3     -0.029273      0.359991          -0.871227          1.099063
# 4     -0.029273      0.359991          -0.871227          1.099063
#
#    Foundation_Slab  Foundation_Stone  Foundation_Wood  BsmtQual_Fa  \
# 0        -0.117851         -0.050746        -0.029273    -0.162364
# 1        -0.117851         -0.050746        -0.029273    -0.162364
# 2        -0.117851         -0.050746        -0.029273    -0.162364
# 3        -0.117851         -0.050746        -0.029273    -0.162364
# 4        -0.117851         -0.050746        -0.029273    -0.162364
#
#    BsmtQual_Gd  BsmtQual_None  BsmtQual_TA  BsmtCond_Gd  BsmtCond_None  \
# 0    -0.856118      -0.150888     1.129957    -0.218022      -0.150888
# 1    -0.856118      -0.150888     1.129957    -0.218022      -0.150888
# 2    -0.856118      -0.150888     1.129957    -0.218022      -0.150888
# 3    -0.856118      -0.150888    -0.884989    -0.218022      -0.150888
# 4    -0.856118      -0.150888     1.129957    -0.218022      -0.150888
#
#    BsmtCond_Po  BsmtCond_TA  BsmtExposure_Gd  BsmtExposure_Mn  \
# 0    -0.041416     0.338384         -0.31593        -0.290678
# 1    -0.041416     0.338384         -0.31593        -0.290678
# 2    -0.041416     0.338384          3.16526        -0.290678
# 3    -0.041416     0.338384         -0.31593        -0.290678
# 4    -0.041416     0.338384         -0.31593        -0.290678
#
#    BsmtExposure_No  BsmtExposure_None  BsmtFinType1_BLQ  BsmtFinType1_GLQ  \
# 0         0.717576          -0.153829          3.055533         -0.634162
# 1         0.717576          -0.153829         -0.327275         -0.634162
# 2        -1.393580          -0.153829         -0.327275          1.576885
# 3         0.717576          -0.153829         -0.327275          1.576885
# 4        -1.393580          -0.153829         -0.327275          1.576885
#
#    BsmtFinType1_LwQ  BsmtFinType1_None  BsmtFinType1_Rec  BsmtFinType1_Unf  \
# 0         -0.234742          -0.150888         -0.325669          -0.65679
# 1          4.259993          -0.150888         -0.325669          -0.65679
# 2         -0.234742          -0.150888         -0.325669          -0.65679
# 3         -0.234742          -0.150888         -0.325669          -0.65679
# 4         -0.234742          -0.150888         -0.325669          -0.65679
#
#    BsmtFinType2_BLQ  BsmtFinType2_GLQ  BsmtFinType2_LwQ  BsmtFinType2_None  \
# 0         -0.150888         -0.106092         -0.178331          -0.153829
# 1         -0.150888         -0.106092         -0.178331          -0.153829
# 2         -0.150888         -0.106092          5.607535          -0.153829
# 3         -0.150888         -0.106092         -0.178331          -0.153829
# 4         -0.150888         -0.106092         -0.178331          -0.153829
#
#    BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_GasA  Heating_GasW  \
# 0          -0.18586          0.394071      0.125109     -0.077648
# 1          -0.18586          0.394071      0.125109     -0.077648
# 2          -0.18586         -2.537615      0.125109     -0.077648
# 3          -0.18586          0.394071      0.125109     -0.077648
# 4          -0.18586          0.394071      0.125109     -0.077648
#
#    Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Fa  HeatingQC_Gd  \
# 0     -0.071858     -0.029273     -0.050746     -0.197853      -0.44215
# 1     -0.071858     -0.029273     -0.050746     -0.197853      -0.44215
# 2     -0.071858     -0.029273     -0.050746     -0.197853      -0.44215
# 3     -0.071858     -0.029273     -0.050746     -0.197853      -0.44215
# 4     -0.071858     -0.029273     -0.050746     -0.197853      -0.44215
#
#    HeatingQC_Po  HeatingQC_TA  CentralAir_Y  Electrical_FuseF  \
# 0     -0.029273      1.560543      0.263813         -0.144841
# 1     -0.029273      1.560543      0.263813         -0.144841
# 2     -0.029273      1.560543      0.263813         -0.144841
# 3     -0.029273     -0.640803      0.263813         -0.144841
# 4     -0.029273      1.560543      0.263813         -0.144841
#
#    Electrical_FuseP  Electrical_Mix  Electrical_SBrkr  KitchenQual_Fa  \
# 0         -0.050746       -0.029273          0.310988        -0.17576
# 1         -0.050746       -0.029273          0.310988        -0.17576
# 2         -0.050746       -0.029273          0.310988        -0.17576
# 3         -0.050746       -0.029273          0.310988        -0.17576
# 4         -0.050746       -0.029273          0.310988        -0.17576
#
#    KitchenQual_Gd  KitchenQual_TA  Functional_Maj2  Functional_Min1  \
# 0       -0.819121        1.008599        -0.058621        -0.156721
# 1       -0.819121        1.008599        -0.058621         6.380775
# 2       -0.819121        1.008599        -0.058621        -0.156721
# 3       -0.819121        1.008599        -0.058621        -0.156721
# 4       -0.819121        1.008599        -0.058621        -0.156721
#
#    Functional_Min2  Functional_Mod  Functional_Sev  Functional_Typ  \
# 0        -0.147893       -0.097506       -0.029273        0.271163
# 1        -0.147893       -0.097506       -0.029273       -3.687818
# 2        -0.147893       -0.097506       -0.029273        0.271163
# 3        -0.147893       -0.097506       -0.029273        0.271163
# 4        -0.147893       -0.097506       -0.029273        0.271163
#
#    FireplaceQu_Fa  FireplaceQu_Gd  FireplaceQu_None  FireplaceQu_Po  \
# 0       -0.144841       -0.601087          1.065497       -0.125109
# 1       -0.144841       -0.601087          1.065497       -0.125109
# 2       -0.144841       -0.601087          1.065497       -0.125109
# 3       -0.144841       -0.601087          1.065497       -0.125109
# 4       -0.144841        1.663653         -0.938529       -0.125109
#
#    FireplaceQu_TA  GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0       -0.523181          -1.236179           -0.110144           -0.236765
# 1       -0.523181           0.808944           -0.110144           -0.236765
# 2       -0.523181           0.808944           -0.110144           -0.236765
# 3       -0.523181           0.808944           -0.110144           -0.236765
# 4       -0.523181           0.808944           -0.110144           -0.236765
#
#    GarageType_CarPort  GarageType_Detchd  GarageType_None  GarageFinish_None  \
# 0           -0.088121           1.678390        -0.244727          -0.244727
# 1           -0.088121          -0.595809        -0.244727          -0.244727
# 2           -0.088121          -0.595809        -0.244727          -0.244727
# 3           -0.088121          -0.595809        -0.244727          -0.244727
# 4           -0.088121          -0.595809        -0.244727          -0.244727
#
#    GarageFinish_RFn  GarageFinish_Unf  GarageQual_Fa  GarageQual_Gd  \
# 0         -0.627531          1.205729      -0.190735      -0.106092
# 1         -0.627531          1.205729      -0.190735      -0.106092
# 2          1.593548         -0.829374      -0.190735      -0.106092
# 3         -0.627531         -0.829374      -0.190735      -0.106092
# 4          1.593548         -0.829374      -0.190735      -0.106092
#
#    GarageQual_None  GarageQual_Po  GarageQual_TA  GarageCond_Fa  \
# 0        -0.244727      -0.050746       0.347737      -0.162364
# 1        -0.244727      -0.050746       0.347737      -0.162364
# 2        -0.244727      -0.050746       0.347737      -0.162364
# 3        -0.244727      -0.050746       0.347737      -0.162364
# 4        -0.244727      -0.050746       0.347737      -0.162364
#
#    GarageCond_Gd  GarageCond_None  GarageCond_Po  GarageCond_TA  PavedDrive_P  \
# 0      -0.071858        -0.244727      -0.077648       0.324059     -0.150888
# 1      -0.071858        -0.244727      -0.077648       0.324059     -0.150888
# 2      -0.071858        -0.244727      -0.077648       0.324059     -0.150888
# 3      -0.071858        -0.244727      -0.077648       0.324059     -0.150888
# 4      -0.071858        -0.244727      -0.077648       0.324059     -0.150888
#
#    PavedDrive_Y  PoolQC_Fa  PoolQC_Gd  PoolQC_None  Fence_GdWo  Fence_MnPrv  \
# 0      0.297551  -0.041416  -0.050746     0.077648    -0.18586     3.025975
# 1      0.297551  -0.041416  -0.050746     0.077648    -0.18586    -0.330472
# 2      0.297551  -0.041416  -0.050746     0.077648    -0.18586    -0.330472
# 3      0.297551  -0.041416  -0.050746     0.077648    -0.18586    -0.330472
# 4      0.297551  -0.041416  -0.050746     0.077648    -0.18586    -0.330472
#
#    Fence_MnWw  Fence_None  MiscFeature_None  MiscFeature_Othr  \
# 0   -0.092928   -2.111384          0.195505         -0.029273
# 1   -0.092928    0.473623          0.195505         -0.029273
# 2   -0.092928    0.473623          0.195505         -0.029273
# 3   -0.092928    0.473623          0.195505         -0.029273
# 4   -0.092928    0.473623          0.195505         -0.029273
#
#    MiscFeature_Shed  MiscFeature_TenC  SaleType_CWD  SaleType_Con  \
# 0         -0.188311         -0.029273     -0.050746     -0.029273
# 1         -0.188311         -0.029273     -0.050746     -0.029273
# 2         -0.188311         -0.029273     -0.050746     -0.029273
# 3         -0.188311         -0.029273     -0.050746     -0.029273
# 4         -0.188311         -0.029273     -0.050746     -0.029273
#
#    SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0       -0.065568       -0.058621       -0.058621     -0.310988     -0.041416
# 1       -0.065568       -0.058621       -0.058621     -0.310988     -0.041416
# 2       -0.065568       -0.058621       -0.058621     -0.310988     -0.041416
# 3       -0.065568       -0.058621       -0.058621     -0.310988     -0.041416
# 4       -0.065568       -0.058621       -0.058621     -0.310988     -0.041416
#
#    SaleType_WD  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0     0.391166              -0.050746             -0.092928
# 1     0.391166              -0.050746             -0.092928
# 2     0.391166              -0.050746             -0.092928
# 3     0.391166              -0.050746             -0.092928
# 4     0.391166              -0.050746             -0.092928
#
#    SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# 0             -0.114059              0.476331               -0.31593
# 1             -0.114059              0.476331               -0.31593
# 2             -0.114059              0.476331               -0.31593
# 3             -0.114059              0.476331               -0.31593
# 4             -0.114059              0.476331               -0.31593

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train_log)
# Out:
# LinearRegression()

# %%
# RidgeCV автоматически подбирает лучший alpha из списка с помощью кросс-валидации
alphas_ridge = [0.01, 0.1, 1.0, 5.0, 10.0, 20.0, 50.0, 100.0] # Примерный набор alpha
ridge_cv = RidgeCV(alphas=alphas_ridge, cv=5) # cv=5 означает 5-fold Cross-Validation
ridge_cv.fit(X_train_scaled, y_train_log)
print(f"     - Лучший alpha для Ridge: {ridge_cv.alpha_}")
# Out:
#      - Лучший alpha для Ridge: 100.0

# %%
#Lasso Регрессия (L1 регуляризация)
alphas_lasso = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1] # Lasso требует меньшие alpha обычно
lasso_cv = LassoCV(alphas=alphas_lasso, cv=5, max_iter=5000, random_state=42) # Увеличим max_iter для сходимости
lasso_cv.fit(X_train_scaled, y_train_log)
print(f"     - Лучший alpha для Lasso: {lasso_cv.alpha_}")
# Out:
#      - Лучший alpha для Lasso: 0.005

# %%
# Оценка моделей (на трейне)

# %%
def rmsle(y_true_log, y_pred_log):
    # Используем MSLE, так как RMSLE = sqrt(MSLE)
    # Предсказания и таргет уже в логарифмах
    return mean_squared_log_error(np.expm1(y_true_log), np.expm1(y_pred_log))

# %%
pred_lr_log = lr.predict(X_train_scaled)
pred_ridge_log = ridge_cv.predict(X_train_scaled)
pred_lasso_log = lasso_cv.predict(X_train_scaled)

msle_lr = rmsle(y_train_log, pred_lr_log)
msle_ridge = rmsle(y_train_log, pred_ridge_log)
msle_lasso = rmsle(y_train_log, pred_lasso_log)
print(f"   - Linear Regression MSLE (train): {msle_lr:.5f} (RMSLE: {np.sqrt(msle_lr):.5f})")
print(f"   - RidgeCV MSLE (train):           {msle_ridge:.5f} (RMSLE: {np.sqrt(msle_ridge):.5f})")
print(f"   - LassoCV MSLE (train):           {msle_lasso:.5f} (RMSLE: {np.sqrt(msle_lasso):.5f})")
# Out:
#    - Linear Regression MSLE (train): 0.00819 (RMSLE: 0.09049)
#    - RidgeCV MSLE (train):           0.01067 (RMSLE: 0.10332)
#    - LassoCV MSLE (train):           0.01362 (RMSLE: 0.11673)

# %%
best_model = ridge_cv
print(f"\n   - Выбрана модель: RidgeCV (alpha={best_model.alpha_})")
# Out:
#    - Выбрана модель: RidgeCV (alpha=100.0)

# %%
# Предсказываем на масштабированных тестовых данных
test_predictions_log = best_model.predict(X_test_scaled)

# Возвращаем предсказания из логарифмической шкалы в обычную
test_predictions = np.expm1(test_predictions_log)

# Убедимся, что нет отрицательных предсказаний (хотя маловероятно после expm1)
test_predictions[test_predictions < 0] = 0

# Создаем DataFrame для отправки
submission_df = pd.DataFrame({
    'Id': test_ids,
    'SalePrice': test_predictions
})

# %%
submission_filename = 'submission_simplified_ridge.csv'
submission_df.to_csv(submission_filename, index=False)

print(f"   - Файл предсказаний '{submission_filename}' успешно сохранен.")
print(f"   - Пример предсказаний:\n{submission_df.head()}")
# Out:
#    - Файл предсказаний 'submission_simplified_ridge.csv' успешно сохранен.
#    - Пример предсказаний:
#    Id      SalePrice
# 0   1  144252.118591
# 1   2  193839.330062
# 2   3  170875.259179
# 3   4  169768.801385
# 4   5  164963.195069
